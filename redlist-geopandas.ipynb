# %%
# !conda install -y -c conda-forge geopandas
# Out:
# Fetching package metadata .............
# Solving package specifications: .
#
# Package plan for installation in environment /home/rsargent/anaconda2:
#
# The following NEW packages will be INSTALLED:
#
#     click-plugins:   1.0.3-py27_0          conda-forge
#     cligj:           0.4.0-py27_0          conda-forge
#     descartes:       1.1.0-py27_0          conda-forge
#     fiona:           1.7.0-py27_0
#     geopandas:       0.3.0-py27_0          conda-forge
#     geotiff:         1.4.1-0
#     hdf4:            4.2.12-0              conda-forge
#     kealib:          1.4.6-3               conda-forge
#     libgdal:         2.1.0-0
#     libnetcdf:       4.4.1-0               conda-forge
#     libspatialindex: 1.8.5-1               conda-forge
#     munch:           2.2.0-py27_0          conda-forge
#     proj4:           4.9.2-0
#     pyproj:          1.9.5.1-py27_0        conda-forge
#     pysal:           1.14.3-py27_0         conda-forge
# ...

# %%
import pandas as pd
import geopandas as gpd
from geopandas import GeoSeries, GeoDataFrame

# %%
# this took maybe 5 or 10 mins
mammals = gpd.read_file('redlist/MAMMALS/MAMMALS.shp')

# %%
mammals
# Out:
#            id_no                          binomial  presence  origin  \
# 0       89604632         Chaetophractus vellerosus         1       1
# 1       89604632         Chaetophractus vellerosus         6       1
# 2          41688                      Ursus arctos         1       1
# 3          41688                      Ursus arctos         1       1
# 4          41540                   Aotus nancymaae         1       1
# 5          41688                      Ursus arctos         1       1
# 6          41688                      Ursus arctos         1       1
# 7          41688                      Ursus arctos         1       1
# 8          41688                      Ursus arctos         1       1
# 9          41688                      Ursus arctos         3       1
# 10         41688                      Ursus arctos         1       1
# 11         41688                      Ursus arctos         1       1
# 12         41688                      Ursus arctos         1       1
# ...

# %%
len(mammals.binomial.unique())
# Out:
# 5549

# %%
print mammals.groupby('binomial')

# %%
mammals.dissolve(by='binomial')
# Out:
# TopologyException: Input geom 1 is invalid: Ring Self-intersection at or near point 75.344566115000077 34.28986369100005 at 75.344566115000077 34.28986369100005
# TopologyException: Input geom 1 is invalid: Ring Self-intersection at or near point 75.344566115000077 34.28986369100005 at 75.344566115000077 34.28986369100005
